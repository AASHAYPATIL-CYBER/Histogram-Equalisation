# %% [markdown]
# <a href="https://colab.research.google.com/github/AASHAYPATIL-CYBER/Histogram-Equalisation/blob/main/Exp3a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import Opencv
import cv2

# import Numpy
import numpy as np
from google.colab.patches import cv2_imshow

# read a image using imread
img = cv2.imread('/content/dogesh.png', 0)

# creating a Histograms Equalization
# of a image using cv2.equalizeHist()
equ = cv2.equalizeHist(img)

# stacking images side-by-side
res = np.hstack((img, equ))

# show image input vs output
cv2_imshow(res)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=200x100>
